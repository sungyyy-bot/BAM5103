# %% [markdown]
# # Python Analyst Basic Gym
#
# ## A 3-hour confidence-building workout
#
# Today is not about memorizing syntax. It is about becoming comfortable using Python to answer business questions, experimenting in a notebook, reading errors, and improving your work one small step at a time.
#
# **By the end of this session, you will remember how to:**
#
# - calculate and format business metrics;
# - work with lists, decisions, loops, functions, and dictionaries;
# - debug common Python mistakes;
# - use a productive VS Code + Jupyter workflow; and
# - save your progress with Git.
#
# > **Gym rule:** predict first, run second, explain third. Being wrong is useful data.
#
# **Tip**: Use the [cheat sheets from our iCampus page](https://canvas.skku.edu/courses/79805/pages/python-basics-and-pandas-cheatsheets?module_item_id=5831387) to help you remember syntax. You can also use the Python documentation, Stack Overflow, and Google to find answers.

# %% [markdown]
# ### How to use this notebook
#
# 1. In VS Code, choose a Python kernel in the top-right corner.
# 2. Read the question and write down your prediction.
# 3. Run a cell with **Shift+Enter**.
# 4. Change a value and run it again. Ask: *what changed, and why?*

# %%
# Run this cell first: it uses only Python's standard library.
from collections import Counter

print("Gym ready — let's work with business data.")

# %% [markdown]
# ---
# ## Exercise 1 — Python speed refresher
#
# For the cell below
#
# - calculate the profit variable
# - print the profit
# - then print the **type** of profit

# %%
revenue = 125_000
cost = 87_000
profit = revenue - cost

print(profit)
print(type(profit))
# Out:
# 38000
# <class 'int'>

# %% [markdown]
# For the cell below
#
# - calculate the total sales value
# - print the sales value
# - print the **type** of profit

# %%
price = 19.99
quantity = 250
sales_value = price * quantity

print(sales_value)
print(type(sales_value))
# Out:
# 4997.5
# <class 'float'>

# %% [markdown]
# ###  Business-ready text
#
# Use an **f-string** to create exactly: `Tesla revenue report 2025`.
# Then format growth as a percentage with one decimal place. Like `Business growth in year XXXX was XX,X%`
#
# Then print the message

# %%
company = "Tesla"
year = 2025
growth = 0.1534

# TODO: replace the placeholders with f-strings.
report_title = f"{company} revenue report {year}"
growth_message = f"Business growth in year {year} was {growth:.1%}"

# Then print the text
print(report_title)
print(growth_message)
# Out:
# Tesla revenue report 2025
# Business growth in year 2025 was 15.3%

# %% [markdown]
# <details><summary><strong>Hint</strong></summary>Put variables inside curly braces: <code>f"{variable}"</code>. Percentage formatting uses <code>:.1%</code>.</details>

# %% [markdown]
# ## Exercise 2 — Business calculator
#
# ROI answers: *How much value did we gain relative to what we invested?*
#
# $$ROI = \frac{benefit - investment}{investment}$$

# %%
investment = 50_000
benefit = 75_000

# TODO: calculate ROI and display: ROI = 50.0%
roi = (benefit - investment) / investment
print(f"ROI = {roi:.1%}")
# Out:
# ROI = 50.0%

# %% [markdown]
# **Stretch:** If `benefit` is the value after 3 years, calculate the compound annualized return. What assumption are we making?

# %% [markdown]
# $$
# \text{Annualized return} = \left(\frac{\text{benefit}}{\text{investment}}\right)^{\frac{1}{\text{years}}} - 1
# $$

# %%
years = 3
# TODO: calculate annualized_return.
annualized_return = (benefit / investment) ** (1 / years) - 1

print(f"Annualized Return = {annualized_return:.2%}")
# Out:
# Annualized Return = 14.47%

# %% [markdown]
# ## Exercise 3 — Lists are your first dataset
#
# One list can represent a row of monthly observations. Use `max()`, `min()`, `len()`, and `sum()`—no pandas yet.

# %%
sales = [120, 140, 135, 160, 180]

# TODO: calculate all four metrics.
highest_sale = max(sales)
lowest_sale = min(sales)
observation_count = len(sales)
average_sale = sum(sales) / len(sales)

print(highest_sale)
print(lowest_sale)
print(observation_count)
print(average_sale)
# Out:
# 180
# 120
# 5
# 147.0

# %% [markdown]
# **Challenge:** append a new month with sales of 210, then recalculate. Run the cell twice—what happens, and why? How could you prevent that?

# %%
# TODO: append 210 and recalculate the average.
#sales.append(210)
#print(sales)

new_sales = sales + [210]

average_sales = sum(new_sales) / len(new_sales)

print(new_sales)
print(average_sales)
# Out:
# [120, 140, 135, 160, 180, 210]
# 157.5

# %% [markdown]
# ## Exercise 4 — Customer segmentation
#
# Translate this policy into an `if / elif / else` decision:
#
# | Annual spend | Segment |
# |---:|---|
# | Under 100 | Bronze |
# | Under 500 | Silver |
# | Under 1,000 | Gold |
# | 1,000 or more | Platinum |

# %%
spend = 750

# TODO: replace this placeholder with the segmentation logic.
if spend < 100:
    segment = "Bronze"
elif spend < 500:
    segment = "Silver"
elif spend < 1000:
    segment = "Gold"
else
    segment = "Platinum"
    
print(segment)
# Out:
# Gold

# %% [markdown]
# **Boundary test:** try `99`, `100`, `499`, `500`, `999`, and `1000`. Boundary values are where business rules often break.

# %% [markdown]
# ## Exercise 5 — Fraud detection lite
#
# Flag a transaction if the amount is over 5,000 **or** it is international. Predict the outcome before running it.

# %%
amount = 9_000
international = True

# TODO: write one Boolean expression.
if amount > 5000 or international == True:
    print("flag transaction")
# Out:
# flag_transaction

# %% [markdown]
# **Make it more realistic:** flag when the amount is over 5000 AND international, OR amount the amount is over 20000. Use parentheses to make the policy obvious.

# %%
# TODO: implement the more realistic rule.

if (amount > 5000 and international == True) or amount > 20000:
    print("flag transaction")
# Out:
# flag transaction

# %% [markdown]
# ## Exercise 6 — Loops with monthly sales
#
# Print one clear line per month

# %%
monthly_sales = [120, 135, 150, 160, 180]

# First: print each sale per line
for i in sales:
    print(i)
# Out:
# 120
# 140
# 135
# 160
# 180

# %% [markdown]
# `enumerate(..., start=1)` gives you both a month number and its value. Let's try that

# %%
# TODO: print 'Month 1: 120', and so on.
for a, b in enumerate(monthly_sales, start=1):
    print(f"Month {a}: {b}")
# Out:
# Month 1: 120
# Month 2: 135
# Month 3: 150
# Month 4: 160
# Month 5: 180

# %% [markdown]
# Using the logic above, now print only the months where sales exceeded 150

# %%
# TODO: print only months where sales exceed 150.

print("Months above target:")

sales_over_150 = []

for a, b in enumerate(monthly_sales, start=1):
    if b > 150:
        sales_over_150.append(a)

print(sales_over_150)
# Your logic here
# Out:
# Months above target:
# [4, 5]

# %% [markdown]
# ## Exercise 7 — Your first KPI dashboard
#
# Calculate four KPIs and print a neat management report.

# %%
dashboard_sales = [120, 140, 160, 180, 190, 210]

# TODO: calculate these values.
total_sales = sum(dashboard_sales)
average_sales = sum(dashboard_sales) / len(dashboard_sales)
highest_sales = max(dashboard_sales)
lowest_sales = min(dashboard_sales)

print(total_sales)
print(int(average_sales))
print(highest_sales)
print(lowest_sales)
# Out:
# 1000
# 166
# 210
# 120

# %% [markdown]
# Print the report

# %%
# TODO: print the report shown in the instructions.

print("SALES REPORT")
print("------------")
print("Total:   [calculate me]") # etc
# Out:
# SALES REPORT
# ------------
# Total:   [calculate me]

# %%
# Reference solution
total_sales = sum(dashboard_sales)
average_sales = total_sales / len(dashboard_sales)
highest_sales = max(dashboard_sales)
lowest_sales = min(dashboard_sales)

print("SALES REPORT")
print("------------")
print(f"Total:   {total_sales:,.0f}")
print(f"Average: {average_sales:,.1f}")
print(f"Highest: {highest_sales:,.0f}")
print(f"Lowest:  {lowest_sales:,.0f}")
# Out:
# SALES REPORT
# ------------
# Total:   1,000
# Average: 166.7
# Highest: 210
# Lowest:  120

# %% [markdown]
# ## Exercise 8 — Reusable business functions

# %%
def calculate_profit(revenue, cost):
    # TODO: return profit.
    return revenue - cost


def calculate_margin(revenue, cost):
    # TODO: return profit as a share of revenue.
    return ((revenue - cost) / revenue)


def customer_value(annual_revenue, years):
    # TODO: use a simple revenue-times-years model.
    return (annual_revenue * years)

# %%
# Use small tests to check your functions.
# Uncomment after implementing them.
# assert calculate_profit(1_000, 700) == 300
# assert calculate_margin(1_000, 700) == 0.3
# assert customer_value(1_000, 3) == 3_000
# print("All tests passed.")

if calculate_profit(1_000, 700) == 300 and calculate_margin(1_000, 700) == 0.3 and customer_value(1_000, 3) == 3_000:
    print("All tests passed")
# Out:
# All tests passed

# %% [markdown]
# **Business edge case:** What should `calculate_margin(0, 0)` do? Try it, read the error, and discuss the policy you would want.

# %% [markdown]
# ## Exercise 9 — Working with dictionaries
#
# A dictionary describes one business entity using named fields.

# %%
customer = {
    "name": "Alice",
    "country": "Singapore",
    "spend": 1_200,
}

print(customer["name"])
# Out:
# Alice

# %% [markdown]
# Add a new key-value pair to the customer dictionary: segment='Gold' and increase spend by 10%. Then print the updated customer dictionary.

# %%
# TODO: add segment='Gold' and increase spend by 10%.

customer["segment"] = "Gold"
print(customer)

customer["spend"] = customer["spend"]*1.1
print(customer)
# Out:
# {'name': 'Bob', 'spend': 300, 'segment': 'Gold'}
# {'name': 'Bob', 'spend': 330.0, 'segment': 'Gold'}

# %% [markdown]
# ## Exercise 10 — Mini CRM
#
# A list of dictionaries resembles a small table. Together, print every name, calculate total spend, and find the highest-spending customer.

# %%
customers = [
    {"name": "Carol", "spend": 700},
    {"name": "Alice", "spend": 1_200},
    {"name": "Bob", "spend": 300},
]

# %%
# TODO 1: loop through customers and print each name.

for customer in customers:
    print(customer["name"])
# Out:
# Carol
# Alice
# Bob

# %%
# TODO 2: calculate total spend.
total_spend = 0

for customer in customers:
    total_spend += customer["spend"]

print(total_spend)
# Out:
# 2200

# %%
# TODO 3: find the highest-spending customer's.

highest_spend = customers[0]

for customer in customers:
    if customer["spend"] > highest_spend["spend"]:
        highest_spend = customer

print(highest_spend["name"])
# Out:
# Alice

# %% [markdown]
# ## Exercise 11 — Debugging race
#
# **(1)** predict the error
# **(2)** run it
# **(3)** read the final line of the message, and
# **(4)** fix it

# %%
sales = [100, 200, 300]
average = sum(sales) / len(sales)

print(average)
# Out:
# 200.0

# %%
client = {'name': 'Asha'}

print(client['name'])
# Out:
# Asha

# %%
units = '12'

print(int(units) + 3)
# Out:
# 15

# %%
quarters = ['Q1', 'Q2']

print(quarters[:2])
# Out:
# ['Q1', 'Q2']

# %%
revenue = 0

margin = 100 / revenue
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[196], line 2
#       1 revenue = 0
# ----> 2 margin = 100 / revenue
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ---
# # Mini business case — Coffee Shop Analytics
#
# You are advising a small coffee shop. Its point-of-sale system exported six orders. Management wants five answers:
#
# 1. What is total revenue?
# 2. How many orders were placed?
# 3. What is average order value?
# 4. What was the most frequently sold product?
# 5. What was revenue by product?
#
# ### Suggested workflow
#
# - Write a plain-language plan before coding.
# - Solve one question at a time and print intermediate results.
# - Check whether your answers reconcile: product revenues must add to total revenue.
# - Prepare a 60-second management summary.

# %%
orders = [
    {"item": "Latte", "price": 5},
    {"item": "Espresso", "price": 3},
    {"item": "Espresso", "price": 3},
    {"item": "Latte", "price": 5},
    {"item": "Tea", "price": 4},
    {"item": "Tea", "price": 4},
    {"item": "Latte", "price": 5},
    {"item": "Tea", "price": 4},
    {"item": "Latte", "price": 5},
    {"item": "Tea", "price": 4},
]

# %% [markdown]
# ### Step 1 — Write your plan
#
# In your own words, describe how you will calculate each answer. Which collection would help you accumulate revenue by product?

# %%
# TODO: calculate the five requested metrics.
case_total_revenue = None
case_order_count = None
case_average_order_value = None
case_most_frequent_product = None
case_revenue_by_product = {}

# %% [markdown]
# <details><summary><strong>Hints</strong></summary><ul><li>A total can be built with <code>sum(...)</code>.</li><li><code>Counter</code> can count item names.</li><li>For revenue by product, start with an empty dictionary. For each order, add its price to the current total; <code>dictionary.get(key, 0)</code> is useful.</li></ul></details>

# %%
# Reference solution
case_total_revenue = sum(order["price"] for order in orders)
case_order_count = len(orders)
case_average_order_value = case_total_revenue / case_order_count

item_counts = Counter(order["item"] for order in orders)
case_most_frequent_product = item_counts.most_common(1)[0][0]

case_revenue_by_product = {}
for order in orders:
    item = order["item"]
    case_revenue_by_product[item] = case_revenue_by_product.get(item, 0) + order["price"]

print("COFFEE SHOP REPORT")
print("------------------")
print(f"Total revenue: ${case_total_revenue:.2f}")
print(f"Orders: {case_order_count}")
print(f"Average order value: ${case_average_order_value:.2f}")
print(f"Most frequent product: {case_most_frequent_product}")
print("Revenue by product:")
for item, item_revenue in case_revenue_by_product.items():
    print(f"  {item}: ${item_revenue:.2f}")

assert sum(case_revenue_by_product.values()) == case_total_revenue
print("Reconciliation check passed.")

# %% [markdown]
# ### Management interpretation
#
# Numbers are not yet a recommendation. Write 2–3 sentences answering:
#
# - What stands out?
# - What can management reasonably conclude from only six orders?
# - What additional data would you request before making a decision?
#
# > Notice the loops, counters, and dictionaries we needed. **Pandas** will help us ask the same questions at scale with fewer lines of code.

# %% [markdown]
# ---
# # 5. VS Code and Git practice (20 minutes)
#
# ## Exercise 12 — VS Code skills challenge
#
# Complete these actions in VS Code:
#
# - **Multi-cursor:** place cursors after all four `=` signs below and enter values.
# - **Rename Symbol:** select `annual_revenue`, press **F2**, and rename it consistently.
# - **Find and Replace:** replace `quarter` with `period` in the practice cell.
# - **Run All:** use the notebook toolbar, then inspect outputs and state.
# - **Restart:** restart the kernel and run top-to-bottom to check reproducibility.

# %%
# Multi-cursor practice: add four numeric values.
q1_sales = None
q2_sales = None
q3_sales = None
q4_sales = None

# Rename and Find/Replace practice
annual_revenue = 500_000
quarter_label = "quarter 1"
print(annual_revenue, quarter_label)

# %% [markdown]
# ---
# # 6. Wrap-up challenge (15 minutes)
#
# Without copying an earlier report, turn the quarterly values below into a compact KPI report. Your report must include total sales, average sales, the strongest quarter, and whether annual sales met the target.

# %%
quarterly_sales = {"Q1": 120_000, "Q2": 135_000, "Q3": 128_000, "Q4": 155_000}
annual_target = 525_000

# TODO: build the final KPI report.
pass

# %%
## Then complete the report with the following metrics:

print("ANNUAL KPI REPORT")
print("-----------------")
print(f"Total sales: [calculate me]") # etc
print(f"Quarterly average: [calculate me]")
print(f"Strongest quarter: [calculate me]")
print(f"Target met: [calculate me]")

# %% [markdown]
# ## Exit ticket
#
# Before you submit your notebook on iCampus, write down:
#
# 1. One Python idea you can now explain to a colleague.
# 2. One error you know how to investigate.
# 3. One business question you want to answer with data.
